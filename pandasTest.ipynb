# %%
list1 = [1,2,3,4,5]
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list2 = ['ab','b',1,2,3]
list2
# Out:
# ['ab', 'b', 1, 2, 3]

# %%
len(list2)
# Out:
# 5

# %%
list2.append(4)

# %%
list2
# Out:
# ['ab', 'b', 1, 2, 3, 4]

# %%
list2.append('c')

# %%
list2
# Out:
# ['ab', 'b', 1, 2, 3, 4, 'c']

# %%
list2.pop()
# Out:
# 'c'

# %%
list2
# Out:
# ['ab', 'b', 1, 2, 3, 4]

# %%
list2.extend(['c','d'])

# %%
list2
# Out:
# ['ab', 'b', 1, 2, 3, 4, 'c', 'd']

# %%
list2.remove(1)
list2
# Out:
# ['b', 2, 3, 4, 'c', 'd']

# %%
list2.extend(['a','aa','aaa','ab',11,12])
list2
# Out:
# ['b', 2, 3, 4, 'c', 'd', 'a', 'aa', 'aaa', 'ab', 11, 12]

# %%
list2.remove('a')

# %%
list2
# Out:
# ['b', 2, 3, 4, 'c', 'd', 'aa', 'aaa', 'ab', 11, 12]

# %%
list2.remove(11)
list2
# Out:
# ['b', 2, 3, 4, 'c', 'd', 'aa', 'aaa', 'ab', 12]

# %%
py_book = ['파이썬 머신러닝', '파이썬 입문', '파이썬 코딩']
py_book
# Out:
# ['파이썬 머신러닝', '파이썬 입문', '파이썬 코딩']

# %%
py_book.append('파이썬 주무르기')
py_book
# Out:
# ['파이썬 머신러닝', '파이썬 입문', '파이썬 코딩', '파이썬 주무르기']

# %%
py_book.insert(1,34200)

# %%
py_book
# Out:
# ['파이썬 머신러닝', 34200, '파이썬 입문', '파이썬 코딩', '파이썬 주무르기']

# %%
py_book.insert(3,15000)
py_book.insert(5,35000)
py_book.insert(7,40000)
py_book
# Out:
# ['파이썬 머신러닝', 34200, '파이썬 입문', 15000, '파이썬 코딩', 35000, '파이썬 주무르기', 40000]

# %%
import pandas as pd

# %%
practice = pd.DataFrame({'날짜':[],'운동':[],'양':[]})
practice
# Out:
# Empty DataFrame
# Columns: [날짜, 운동, 양]
# Index: []

# %%
practice.loc[0] = ['19-3-1','달리기',1]
practice
# Out:
#        날짜   운동    양
# 0  19-3-1  달리기  1.0

# %%
practice.loc[1] = ['19-3-2','걷기',1]
practice.loc[2] = ['19-3-3','달리기',1]
practice.loc[3] = ['19-3-4','계단오르기',1]
practice
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-3    달리기  1.0
# 3  19-3-4  계단오르기  1.0

# %%
practice.to_csv("./practice2.csv",encoding='utf-8')

# %%
pd.read_csv("./practice2.csv",encoding='utf-8')
# Out:
#    Unnamed: 0      날짜     운동    양
# 0           0  19-3-1    달리기  1.0
# 1           1  19-3-2     걷기  1.0
# 2           2  19-3-3    달리기  1.0
# 3           3  19-3-4  계단오르기  1.0

# %%
pd.read_csv("./practice2.csv",index_col=0,encoding='utf-8')
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-3    달리기  1.0
# 3  19-3-4  계단오르기  1.0

# %%
practice1= pd.read_csv("./practice2.csv",index_col=0,encoding='utf-8')
practice1
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-3    달리기  1.0
# 3  19-3-4  계단오르기  1.0

# %%
practice1.pivot_table(index="운동")
# Out:
#          양
# 운동
# 걷기     1.0
# 계단오르기  1.0
# 달리기    1.0

# %%
import numpy as np

# %%
practice1.pivot_table(index="운동",aggfunc=np.sum)
# Out:
#          양
# 운동
# 걷기     1.0
# 계단오르기  1.0
# 달리기    2.0

# %%
practice1.pivot_table(index="운동",aggfunc=[np.sum,len])
# Out:
#        sum len
#          양  날짜    양
# 운동
# 걷기     1.0   1  1.0
# 계단오르기  1.0   1  1.0
# 달리기    2.0   2  2.0

# %%
practice1.pivot('날짜','운동','양')
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 19-3-1  NaN    NaN  1.0
# 19-3-2  1.0    NaN  NaN
# 19-3-3  NaN    NaN  1.0
# 19-3-4  NaN    1.0  NaN

# %%
practice1.pivot('날짜','양')
# Out:
#            운동
# 양         1.0
# 날짜
# 19-3-1    달리기
# 19-3-2     걷기
# 19-3-3    달리기
# 19-3-4  계단오르기

# %%
practice1.pivot('날짜','운동')
# Out:
#           양
# 운동       걷기 계단오르기  달리기
# 날짜
# 19-3-1  NaN   NaN  1.0
# 19-3-2  1.0   NaN  NaN
# 19-3-3  NaN   NaN  1.0
# 19-3-4  NaN   1.0  NaN

# %%
practice1.pivot('날짜','운동','양')
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 19-3-1  NaN    NaN  1.0
# 19-3-2  1.0    NaN  NaN
# 19-3-3  NaN    NaN  1.0
# 19-3-4  NaN    1.0  NaN

# %%
practice1.pivot('운동','날짜','양')
# Out:
# 날짜     19-3-1  19-3-2  19-3-3  19-3-4
# 운동
# 걷기        NaN     1.0     NaN     NaN
# 계단오르기     NaN     NaN     NaN     1.0
# 달리기       1.0     NaN     1.0     NaN

# %%
prac_pivot = practice.pivot('날짜','운동','양')
prac_pivot.fillna(0,inplace=True)
prac_pivot
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 19-3-1  0.0    0.0  1.0
# 19-3-2  1.0    0.0  0.0
# 19-3-3  0.0    0.0  1.0
# 19-3-4  0.0    1.0  0.0

# %%
not_exercise = pd.read_table("./reason_not_exercise.txt")
not_exercise.head()
# Out:
#      기간  대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0  2019  서울시  서울시               46.8               5.0               4.3
# 1  2019   성별   남자               52.4               4.4               4.9
# 2  2019   성별   여자               42.5               5.6               3.9
# 3  2019  연령별  10대               55.3               4.8               3.9
# 4  2019  연령별  20대               46.0               4.2               4.5
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0      37.3                5.2  1.4
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1

# %%
not_exercise.drop(columns='기간',inplace=True)
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시           서울시               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2      성별            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     연령별           20대               46.0               4.2
# 5     연령별           30대               59.9               5.2
# 6     연령별           40대               54.1               3.9
# 7     연령별           50대               46.1               6.2
# 8     연령별        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    학력별         고졸 이하               44.3               5.3
# 11    학력별         대졸 이하               53.1               4.7
# 12    학력별        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
not_exercise.drop(index=17,inplace=True)
not_exercise
# Out:
#     대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0   서울시           서울시               46.8               5.0               4.3
# 1    성별            남자               52.4               4.4               4.9
# 2    성별            여자               42.5               5.6               3.9
# 3   연령별           10대               55.3               4.8               3.9
# 4   연령별           20대               46.0               4.2               4.5
# 5   연령별           30대               59.9               5.2               2.9
# 6   연령별           40대               54.1               3.9               2.9
# 7   연령별           50대               46.1               6.2               4.5
# 8   연령별        60대 이상               26.6               6.0               6.6
# 9   학력별         중졸 이하               24.7               6.2               4.8
# 10  학력별         고졸 이하               44.3               5.3               5.6
# ...

# %%
not_exercise['대분류']=='성별'
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# Name: 대분류, dtype: bool

# %%
not_ex_sex = not_exercise[not_exercise['대분류']=='성별'].copy()
not_ex_sex
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  성별  남자               52.4               4.4               4.9      32.4
# 2  성별  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
test_a = [1,2,3,4]
test_b = test_a
test_b[2] = 0
test_a
# Out:
# [1, 2, 0, 4]

# %%
test_a = [1,2,3,4]
test_c = test_a.copy()
test_c[2] = 0
test_a
# Out:
# [1, 2, 3, 4]

# %%
not_ex_sex.drop(columns='대분류',inplace=True)
not_ex_sex
# Out:
#    분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  남자               52.4               4.4               4.9      32.4
# 2  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
not_ex_sex.set_index('분류',inplace=True)
not_ex_sex
# Out:
#     운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 남자               52.4               4.4               4.9      32.4
# 여자               42.5               5.6               3.9      41.0
#
#     운동을 할 충분한 비용이 없어서   기타
# 분류
# 남자                4.9  1.1
# 여자                5.4  1.7

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus']=False

f_path = "C:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=f_path).get_name()
rc('font',family=font_name)

# %%
f, ax = plt.subplots(1,2,figsize=(16,8))

not_ex_sex['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0,0.02],ax=ax[0],autopct='%1.1f%%')
ax[0].set_title('운동을 할 시간이 없어서')
ax[0].set_ylabel('')

not_ex_sex['운동을 싫어해서'].plot.pie(explode=[0,0.02],ax=ax[1],autopct='%1.1f%%')
ax[1].set_title('운동을 할 시간이 없어서')
ax[1].set_ylabel('')

plt.show()

# %%
not_exercise
# Out:
#     대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0   서울시           서울시               46.8               5.0               4.3
# 1    성별            남자               52.4               4.4               4.9
# 2    성별            여자               42.5               5.6               3.9
# 3   연령별           10대               55.3               4.8               3.9
# 4   연령별           20대               46.0               4.2               4.5
# 5   연령별           30대               59.9               5.2               2.9
# 6   연령별           40대               54.1               3.9               2.9
# 7   연령별           50대               46.1               6.2               4.5
# 8   연령별        60대 이상               26.6               6.0               6.6
# 9   학력별         중졸 이하               24.7               6.2               4.8
# 10  학력별         고졸 이하               44.3               5.3               5.6
# ...

# %%
no_ex_age = not_exercise[not_exercise['대분류']=='연령별'].copy()

# %%
no_ex_age
# Out:
#    대분류      분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 3  연령별     10대               55.3               4.8               3.9
# 4  연령별     20대               46.0               4.2               4.5
# 5  연령별     30대               59.9               5.2               2.9
# 6  연령별     40대               54.1               3.9               2.9
# 7  연령별     50대               46.1               6.2               4.5
# 8  연령별  60대 이상               26.6               6.0               6.6
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1
# 5      27.3                4.5  0.2
# 6      35.5                3.3  0.4
# 7      36.8                5.6  0.8
# 8      48.7                6.6  5.6

# %%
no_ex_age.drop(columns='대분류',inplace=True)
no_ex_age.set_index('분류',inplace=True)
no_ex_age
# Out:
#         운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 10대                  55.3               4.8               3.9      32.6
# 20대                  46.0               4.2               4.5      38.8
# 30대                  59.9               5.2               2.9      27.3
# 40대                  54.1               3.9               2.9      35.5
# 50대                  46.1               6.2               4.5      36.8
# 60대 이상               26.6               6.0               6.6      48.7
#
#         운동을 할 충분한 비용이 없어서   기타
# 분류
# 10대                   3.5    -
# 20대                   6.4  0.1
# 30대                   4.5  0.2
# 40대                   3.3  0.4
# 50대                   5.6  0.8
# 60대 이상                6.6  5.6

# %%
f, ax = plt.subplots(1,3,figsize=(16,8))

explode_set = [0.1,0.02,0.02,0.02,0.02,0.02]
no_ex_age['운동을 할 충분한 시간이 없어서'].plot.pie(explode=explode_set,ax=ax[0],autopct='%1.1f%%')
ax[0].set_title('시간이 없어서')
ax[0].set_ylabel('')

no_ex_age['함께 운동을 할 사람이 없어서'].plot.pie(explode=explode_set,ax=ax[1],autopct='%1.1f%%')
ax[1].set_title('친구가 없어서')
ax[1].set_ylabel('')

no_ex_age['운동을 할 충분한 비용이 없어서'].plot.pie(explode=explode_set,ax=ax[2],autopct='%1.1f%%')
ax[2].set_title('돈이 없어서')
ax[2].set_ylabel('')

plt.show()
